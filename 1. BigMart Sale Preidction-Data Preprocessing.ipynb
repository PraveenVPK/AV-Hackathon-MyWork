# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline

# %%
train = pd.read_csv("Train_UWu5bXk.csv")
test = pd.read_csv("Test_u94Q5KV.csv")
sample_submit = pd.read_csv("SampleSubmission_TmnO39y.csv")

# %%
sample_submit.head()
# Out:
#   Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           FDW58            OUT049                NaN
# 1           FDW14            OUT017                NaN
# 2           NCN55            OUT010                NaN
# 3           FDQ58            OUT017                NaN
# 4           FDY38            OUT027                NaN

# %%
train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
train.columns.difference(test.columns)
# Out:
# Index(['Item_Outlet_Sales'], dtype='object')

# %%
print("train size :",train.shape)
print("test size :",test.shape)
# Out:
# train size : (8523, 12)
# test size : (5681, 11)

# %%
train["source"] = "train"
test["source"] = "test"

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales source
# 0  Supermarket Type1          3735.1380  train
# 1  Supermarket Type2           443.4228  train
# 2  Supermarket Type1          2097.2700  train
# 3      Grocery Store           732.3800  train
# 4  Supermarket Type1           994.7052  train

# %%
dataf = pd.concat([train,test],axis=0)

# %%
dataf.isnull().sum()
# Out:
# Item_Fat_Content                0
# Item_Identifier                 0
# Item_MRP                        0
# Item_Outlet_Sales            5681
# Item_Type                       0
# Item_Visibility                 0
# Item_Weight                  2439
# Outlet_Establishment_Year       0
# Outlet_Identifier               0
# Outlet_Location_Type            0
# Outlet_Size                  4016
# Outlet_Type                     0
# source                          0
# dtype: int64

# %%
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14204 entries, 0 to 5680
# Data columns (total 13 columns):
# Item_Fat_Content             14204 non-null object
# Item_Identifier              14204 non-null object
# Item_MRP                     14204 non-null float64
# Item_Outlet_Sales            8523 non-null float64
# Item_Type                    14204 non-null object
# Item_Visibility              14204 non-null float64
# Item_Weight                  11765 non-null float64
# Outlet_Establishment_Year    14204 non-null int64
# Outlet_Identifier            14204 non-null object
# Outlet_Location_Type         14204 non-null object
# Outlet_Size                  10188 non-null object
# Outlet_Type                  14204 non-null object
# source                       14204 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.5+ MB

# %%
dataf.describe()
# Out:
#            Item_MRP  Item_Outlet_Sales  Item_Visibility   Item_Weight  \
# count  14204.000000        8523.000000     14204.000000  11765.000000
# mean     141.004977        2181.288914         0.065953     12.792854
# std       62.086938        1706.499616         0.051459      4.652502
# min       31.290000          33.290000         0.000000      4.555000
# 25%       94.012000         834.247400         0.027036      8.710000
# 50%      142.247000        1794.331000         0.054021     12.600000
# 75%      185.855600        3101.296400         0.094037     16.750000
# max      266.888400       13086.964800         0.328391     21.350000
#
#        Outlet_Establishment_Year
# count               14204.000000
# mean                 1997.830681
# std                     8.371664
# min                  1985.000000
# 25%                  1987.000000
# 50%                  1999.000000
# 75%                  2004.000000
# max                  2009.000000

# %%
dataf.nunique()
# Out:
# Item_Fat_Content                 5
# Item_Identifier               1559
# Item_MRP                      8052
# Item_Outlet_Sales             3493
# Item_Type                       16
# Item_Visibility              13006
# Item_Weight                    415
# Outlet_Establishment_Year        9
# Outlet_Identifier               10
# Outlet_Location_Type             3
# Outlet_Size                      3
# Outlet_Type                      4
# source                           2
# dtype: int64

# %%
dataf.shape
# Out:
# (14204, 13)

# %%
dataf.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-5b8e527882c1> in <module>()
# ----> 1 dataf.isna().sum()
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
import pandas_profiling
# Out:
# C:\Users\hp\Anaconda31\lib\site-packages\pandas_profiling\plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\hp\Anaconda31\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\hp\Anaconda31\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\hp\Anaconda31\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\hp\Anaconda31\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Users\hp\Anaconda31\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\hp\Anaconda31\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\hp\Anaconda31\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\interactiveshell.py", line 2808, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-2e28272f0781>", line 4, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\interactiveshell.py", line 2146, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\interactiveshell.py", line 2067, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-108>", line 2, in matplotlib
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\magics\pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\interactiveshell.py", line 2930, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\IPython\core\pylabtools.py", line 307, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\matplotlib\pyplot.py", line 229, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\matplotlib\__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "C:\Users\hp\Anaconda31\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "C:\Users\hp\Anaconda31\lib\site-packages\matplotlib\backends\__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use(BACKEND)

# %%
pandas_profiling.ProfileReport(dataf)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>14 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>14204 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>6.1% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>112.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Item_Identifier"><code>Item_Identifier</code></a> has a high cardinality: 1559 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Item_Outlet_Sales"><code>Item_Outlet_Sales</code></a> has 5681 / 40.0% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Item_Visibility"><code>Item_Visibility</code></a> has 879 / 6.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Item_Weight"><code>Item_Weight</code></a> has 2439 / 17.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Outlet_Size"><code>Outlet_Size</code></a> has 4016 / 28.3% missing values <span class="label label-default">Missing</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Item_Fat_Content">Item_Fat_Content<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>5</td>
#         </tr>

# %%
dataf["Item_Identifier"].value_counts()
# Out:
# FDE28    10
# FDH41    10
# FDJ41    10
# FDY35    10
# FDA52    10
# FDJ57    10
# FDV09    10
# FDV28    10
# FDB38    10
# DRK37    10
# NCP55    10
# FDD51    10
# FDU45    10
# FDP59    10
# FDM09    10
# DRC25    10
# FDH52    10
# NCQ42    10
# FDE21    10
# DRE15    10
# FDR47    10
# FDS45    10
# FDA38    10
# FDM22    10
# FDS01    10
# DRA59    10
# FDP15    10
# NCE31    10
# FDH21    10
# FDN15    10
#          ..
# FDK60     8
# NCN17     8
# NCB42     8
# FDC58     8
# FDA58     8
# DRJ49     8
# FDP08     8
# FDF50     8
# FDL24     8
# FDI09     8
# FDF47     8
# FDL08     8
# FDE32     8
# FDI33     8
# FDY44     8
# FDI44     8
# FDU47     8
# FDM50     7
# FDH58     7
# FDR51     7
# DRN11     7
# FDI46     7
# FDO33     7
# NCL42     7
# FDX49     7
# FDL50     7
# NCW54     7
# FDM10     7
# FDM52     7
# FDS22     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
dataf["Item_Weight"] = dataf.groupby("Item_Identifier").Item_Weight.transform(lambda x : x.fillna(x.mean()))

# %%
dataf.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-5b8e527882c1> in <module>()
# ----> 1 dataf.isna().sum()
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
dataf.Outlet_Size.value_counts()
# Out:
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
def applymode(x):
    a = x.mode()[0]
    print(a)
    return x.fillna(a)

# %%
dataf["Outlet_Size"]=dataf.groupby("Outlet_Type").Outlet_Size.transform(applymode)
# Out:
# Small
# Small
# Medium
# Medium

# %%
dataf["Outlet_Size"].value_counts()
# Out:
# Small     7996
# Medium    4655
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
dataf.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-5b8e527882c1> in <module>()
# ----> 1 dataf.isna().sum()
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
dataf.Item_Visibility.value_counts()
# Out:
# 0.000000    879
# 0.076856      3
# 0.076841      3
# 0.077290      3
# 0.077169      3
# 0.076975      3
# 0.077011      3
# 0.076792      3
# 0.076483      3
# 0.046899      2
# 0.159844      2
# 0.135708      2
# 0.135944      2
# 0.072298      2
# 0.136008      2
# 0.136896      2
# 0.203401      2
# 0.081788      2
# 0.075049      2
# 0.058369      2
# 0.104784      2
# 0.080131      2
# 0.072411      2
# 0.024635      2
# 0.052069      2
# 0.079968      2
# 0.179192      2
# 0.079806      2
# 0.121767      2
# 0.080625      2
#            ...
# 0.013147      1
# 0.098790      1
# 0.073397      1
# 0.137756      1
# 0.017937      1
# 0.105126      1
# 0.044156      1
# 0.141639      1
# 0.094411      1
# 0.074883      1
# 0.039236      1
# 0.044497      1
# 0.051147      1
# 0.175061      1
# 0.039034      1
# 0.077508      1
# 0.078943      1
# 0.077170      1
# 0.042959      1
# 0.013173      1
# 0.069939      1
# 0.011305      1
# 0.069042      1
# 0.012216      1
# 0.064142      1
# 0.209684      1
# 0.019592      1
# 0.013530      1
# 0.008772      1
# 0.066817      1
# Name: Item_Visibility, Length: 13006, dtype: int64

# %%
dataf.loc[dataf.Item_Visibility==0.000000,"Item_Visibility"]=np.nan

# %%
dataf.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-5b8e527882c1> in <module>()
# ----> 1 dataf.isna().sum()
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
dataf["Item_Visibility"] = dataf.groupby("Item_Identifier").Item_Visibility.transform(lambda x : x.fillna(x.median()))

# %%
dataf.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-5b8e527882c1> in <module>()
# ----> 1 dataf.isna().sum()
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
dataf.Item_Fat_Content.value_counts()

# %%
dataf["Item_Fat_Content"] = dataf.Item_Fat_Content.replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'})

# %%
dataf.Item_Fat_Content.value_counts()
# Out:
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64

# %%
dataf.source.unique()
# Out:
# array(['train', 'test'], dtype=object)

# %%
dataf["Toatal_Years_Outlet"] = 2018-dataf["Outlet_Establishment_Year"]

# %%
dataf.drop(columns="Outlet_Establishment_Year",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-fc402442c027> in <module>()
# ----> 1 dataf.drop(columns="Outlet_Establishment_Year",inplace=True)
#
# TypeError: drop() got an unexpected keyword argument 'columns'

# %%
dataf["Item_Identifier_Pattern"]=dataf['Item_Identifier'].apply(lambda x: x[0:2])

# %%
pandas_profiling.ProfileReport(dataf)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>16 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>14204 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>2.5% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.7 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>128.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Item_Identifier"><code>Item_Identifier</code></a> has a high cardinality: 1559 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Item_Outlet_Sales"><code>Item_Outlet_Sales</code></a> has 5681 / 40.0% missing values <span class="label label-default">Missing</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Item_Fat_Content">Item_Fat_Content<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>2</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (n)</th>
#             <td>0</td>
#         </tr>
#     </table>
# </div>
# <div class="col-md-6 collapse in" id="minifreqtable-7334423917268338909">
#     <table class="mini freq">
#         <tr class="">
#     <th>

# %%
dataf.columns
# Out:
# Index(['Item_Fat_Content', 'Item_Identifier', 'Item_MRP', 'Item_Outlet_Sales',
#        'Item_Type', 'Item_Visibility', 'Item_Weight',
#        'Outlet_Establishment_Year', 'Outlet_Identifier',
#        'Outlet_Location_Type', 'Outlet_Size', 'Outlet_Type', 'source',
#        'Toatal_Years_Outlet', 'Item_Identifier_Pattern'],
#       dtype='object')

# %%
dataf.Item_Type.value_counts()
# Out:
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64

# %%
dataf.loc[dataf.Outlet_Type.str.startswith("Supermarket"),"Outlet_Type_Pattern"]="SuperMarket"

# %%
dataf.loc[dataf.Outlet_Type.str.startswith("Grocery"),"Outlet_Type_Pattern"]="Grocery"

# %%
dataf.Outlet_Type_Pattern.value_counts()
# Out:
# SuperMarket    12399
# Grocery         1805
# Name: Outlet_Type_Pattern, dtype: int64

# %%
data_column_category = dataf.select_dtypes(exclude=[np.number]).columns

# %%
data_column_Integer = dataf.columns.difference(data_column_category)

# %%
dataf[data_column_category].nunique()
# Out:
# Item_Fat_Content              2
# Item_Identifier            1559
# Item_Type                    16
# Outlet_Identifier            10
# Outlet_Location_Type          3
# Outlet_Size                   3
# Outlet_Type                   4
# source                        2
# Item_Identifier_Pattern       3
# Outlet_Type_Pattern           2
# dtype: int64

# %%
dataf_one_hot = pd.get_dummies(dataf[data_column_category].drop(columns = "Item_Identifier"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-8fca7e03b631> in <module>()
# ----> 1 dataf_one_hot = pd.get_dummies(dataf[data_column_category].drop(columns = "Item_Identifier"))
#
# TypeError: drop() got an unexpected keyword argument 'columns'

# %%
data_model = pd.concat([dataf["Outlet_Identifier"],dataf_one_hot,dataf["Item_Identifier"],dataf[data_column_Integer]],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-728e2d17a913> in <module>()
# ----> 1 data_model = pd.concat([dataf["Outlet_Identifier"],dataf_one_hot,dataf["Item_Identifier"],dataf[data_column_Integer]],axis=1)
#
# NameError: name 'dataf_one_hot' is not defined

# %%
data_model.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-bb0a638d5559> in <module>()
# ----> 1 data_model.shape
#
# NameError: name 'data_model' is not defined

# %%
train_modified = data_model.loc[:,data_model.source_train==1.0]
#df.loc[:, df.columns != 'b']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-4dbd9f4a4c0c> in <module>()
# ----> 1 train_modified = data_model.loc[:,data_model.source_train==1.0]
#       2 #df.loc[:, df.columns != 'b']
#
# NameError: name 'data_model' is not defined

# %%
test_modified = data_model.loc[data_model.source_train==0.0,:]

# %%
test_modified.shape
# Out:
# (5681, 52)

# %%
train_modified.shape
# Out:
# (8523, 52)

# %%
test_modified.columns
# Out:
# Index(['Outlet_Identifier', 'Item_Fat_Content_Low Fat',
#        'Item_Fat_Content_Regular', 'Item_Type_Baking Goods',
#        'Item_Type_Breads', 'Item_Type_Breakfast', 'Item_Type_Canned',
#        'Item_Type_Dairy', 'Item_Type_Frozen Foods',
#        'Item_Type_Fruits and Vegetables', 'Item_Type_Hard Drinks',
#        'Item_Type_Health and Hygiene', 'Item_Type_Household', 'Item_Type_Meat',
#        'Item_Type_Others', 'Item_Type_Seafood', 'Item_Type_Snack Foods',
#        'Item_Type_Soft Drinks', 'Item_Type_Starchy Foods',
#        'Outlet_Identifier_OUT010', 'Outlet_Identifier_OUT013',
#        'Outlet_Identifier_OUT017', 'Outlet_Identifier_OUT018',
#        'Outlet_Identifier_OUT019', 'Outlet_Identifier_OUT027',
#        'Outlet_Identifier_OUT035', 'Outlet_Identifier_OUT045',
#        'Outlet_Identifier_OUT046', 'Outlet_Identifier_OUT049',
#        'Outlet_Size_High', 'Outlet_Size_Medium', 'Outlet_Size_Small',
#        'Outlet_Location_Type_Tier 1', 'Outlet_Location_Type_Tier 2',
#        'Outlet_Location_Type_Tier 3', 'Outlet_Type_Grocery Store',
#        'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
#        'Outlet_Type_Supermarket Type3', 'source_test', 'source_train',
#        'Item_Identifier_Pattern_DR', 'Item_Identifier_Pattern_FD',
#        'Item_Identifier_Pattern_NC', 'Outlet_Type_Pattern_Grocery',
#        'Outlet_Type_Pattern_SuperMarket', 'Item_Identifier', 'Item_MRP',
#        'Item_Outlet_Sales', 'Item_Visibility', 'Item_Weight',
#        'Toatal_Years_Outlet'],
#       dtype='object')

# %%
test_modified.drop(columns=['source_test', 'source_train','Item_Outlet_Sales'],inplace=True)
# Out:
# /anaconda3/envs/seq2seq/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
train_modified.drop(columns=['source_test', 'source_train'],inplace=True)
# Out:
# /anaconda3/envs/seq2seq/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
train_modified.to_csv("train_ready_for_model.csv",index=False)

# %%
test_modified.to_csv("test_ready_for_model.csv",index=False)

# %% [markdown]
# Modelling
